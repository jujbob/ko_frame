# %%
# !pip install transformers
# !pip install datasets
# !pip install seqeval
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.9/dist-packages (4.28.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.11.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (0.14.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: datasets in /usr/local/lib/python3.9/dist-packages (2.11.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (6.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.9/dist-packages (from datasets) (3.2.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.9/dist-packages (from datasets) (0.70.14)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (0.3.6)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (4.65.0)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.9/dist-packages (from datasets) (0.18.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (2023.4.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (0.14.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from datasets) (23.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.9/dist-packages (from datasets) (3.8.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from datasets) (1.22.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (2.27.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (1.9.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.11.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (1.26.15)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: seqeval in /usr/local/lib/python3.9/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.9/dist-packages (from seqeval) (1.22.4)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.9/dist-packages (from seqeval) (1.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.21.3->seqeval) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.2.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.10.1)

# %%
import os
import itertools
import pandas as pd
import numpy as np
from datasets import Dataset
from datasets import load_metric
from transformers import AutoTokenizer
from transformers import AutoModelForTokenClassification, TrainingArguments, Trainer
from transformers import DataCollatorForTokenClassification
import torch

# %%
label_set = set()
tokens = []
pos_tags = []
token = []
pos_tag = []
with open('train.csv') as file:
  for line in file:
    line = line.strip()    
    if len(line) == 0:
      tokens.append(token)
      pos_tags.append(pos_tag)
      token = []
      pos_tag = []
    else:    
      words = line.split("\t")
      label_set.add(words[-1])
      token.append(words[0])
      pos_tag.append(words[-1])

label_list = list(label_set)

label_encoding_dict = {}
for i in range(len(label_list)):
  label_encoding_dict[label_list[i]] = i

train_df = pd.DataFrame({'tokens':tokens, 'pos_tags': pos_tags})

# %%
tokens = []
pos_tags = []
token = []
pos_tag = []
with open('dev.csv') as file:
  for line in file:
    line = line.strip()    
    if len(line) == 0:
      tokens.append(token)
      pos_tags.append(pos_tag)
      token = []
      pos_tag = []
    else:    
      words = line.split("\t")
      label_set.add(words[-1])
      token.append(words[0])
      pos_tag.append(words[-1])

dev_df = pd.DataFrame({'tokens':tokens, 'pos_tags': pos_tags})

train_dataset = Dataset.from_pandas(train_df)
dev_dataset = Dataset.from_pandas(dev_df)

# %%
def tokenize_and_align_labels(examples):
    label_all_tokens = True
    tokenized_inputs = tokenizer(list(examples["tokens"]), truncation=True, is_split_into_words=True)

    labels = []
    for i, label in enumerate(examples[f"{task}_tags"]):
        word_ids = tokenized_inputs.word_ids(batch_index=i)
        previous_word_idx = None
        label_ids = []
        for word_idx in word_ids:
            if word_idx is None:
                label_ids.append(-100)
            elif label[word_idx] == '0':
                label_ids.append(0)
            elif word_idx != previous_word_idx:
                label_ids.append(label_encoding_dict[label[word_idx]])
            else:
                label_ids.append(label_encoding_dict[label[word_idx]] if label_all_tokens else -100)
            previous_word_idx = word_idx
        labels.append(label_ids)
        
    tokenized_inputs["labels"] = labels
    return tokenized_inputs

# %%
task = "pos" 
batch_size = 16

# %%
# ### DIDN'T work
# # # !pip install datsets transformers[sentencepiece]
# # # !pip install sentencepiece
# # from transformers import T5Tokenizer, T5ForConditionalGeneration
# # tokenizer = T5Tokenizer.from_pretrained(model_checkpoint)

# from transformers import AutoModel, AutoTokenizer
model_checkpoint = "snunlp/KR-BERT-char16424"
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

# %%
# from transformers import AutoTokenizer, AutoModelForCausalLM 

# model_checkpoint = "kakaobrain/kogpt"
# tokenizer = AutoTokenizer.from_pretrained(
#   'kakaobrain/kogpt', revision='KoGPT6B-ryan1.5b-float16',  # or float32 version: revision=KoGPT6B-ryan1.5b
#   bos_token='[BOS]', eos_token='[EOS]', unk_token='[UNK]', pad_token='[PAD]', mask_token='[MASK]')

# %%
train_tokenized_datasets = train_dataset.map(tokenize_and_align_labels, batched=True)
dev_tokenized_datasets = dev_dataset.map(tokenize_and_align_labels, batched=True)
# Out:
# Map:   0%|          | 0/16228 [00:00<?, ? examples/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Map:   0%|          | 0/1418 [00:00<?, ? examples/s]

# %%
# !pip install accelerate #   low_cpu_mem_usage=True

# %%
model = AutoModelForTokenClassification.from_pretrained(model_checkpoint, num_labels=len(label_list))

# model = AutoModelForCausalLM.from_pretrained(
#   'kakaobrain/kogpt', revision='KoGPT6B-ryan1.5b-float16',  # or float32 version: revision=KoGPT6B-ryan1.5b
#   pad_token_id=tokenizer.eos_token_id,
#   num_labels=len(label_list),
#   torch_dtype='auto',
#   low_cpu_mem_usage=True
# ).to(device='cuda', non_blocking=True)
# # _ = model.eval()


args = TrainingArguments(
    f"test-{task}",
    evaluation_strategy = "epoch",
    learning_rate=1e-4,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=3,
    weight_decay=1e-5,
)

data_collator = DataCollatorForTokenClassification(tokenizer)
metric = load_metric("seqeval")


def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)

    true_predictions = [[label_list[p] for (p, l) in zip(prediction, label) if l != -100] for prediction, label in zip(predictions, labels)]
    true_labels = [[label_list[l] for (p, l) in zip(prediction, label) if l != -100] for prediction, label in zip(predictions, labels)]

    results = metric.compute(predictions=true_predictions, references=true_labels)
    return results
    
trainer = Trainer(
    model,
    args,
    train_dataset=train_tokenized_datasets,
    eval_dataset=dev_tokenized_datasets,
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)
# Out:
# Some weights of the model checkpoint at snunlp/KR-BERT-char16424 were not used when initializing BertForTokenClassification: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at snunlp/KR-BERT-char16424 and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.9/dist-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='3045' max='3045' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3045/3045 10:24, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Conj</th>
#       <th>Dj</th>
#       <th>Dp</th>
#       <th>Dv</th>
#       <th>Erb</th>
#       <th>Et</th>
#       <th>Ntj</th>
#       <th>Onj</th>
#       <th>Oun</th>
#       <th>Ropn</th>
#       <th>Rt</th>
#       <th>Um</th>
#       <th>Unct</th>
#       <th>Ym</th>
#       <th> </th>
#       <th>Overall Precision</th>
#       <th>Overall Recall</th>
#       <th>Overall F1</th>
#       <th>Overall Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.120100</td>
#       <td>0.093417</td>
#       <td>{'precision': 0.90625, 'recall': 0.9666666666666667, 'f1': 0.9354838709677419, 'number': 120}</td>
#       <td>{'precision': 0.9276807980049875, 'recall': 0.9230769230769231, 'f1': 0.9253731343283582, 'number': 806}</td>
#       <td>{'precision': 0.6956521739130435, 'recall': 0.8205128205128205, 'f1': 0.7529411764705882, 'number': 39}</td>
#       <td>{'precision': 0.959375, 'recall': 0.9654088050314465, 'f1': 0.9623824451410659, 'number': 954}</td>
#       <td>{'precision': 0.9587824984147115, 'recall': 0.9720347155255545, 'f1': 0.9653631284916201, 'number': 3111}</td>
#       <td>{'precision': 0.9734693877551021, 'recall': 0.9896265560165975, 'f1': 0.9814814814814816, 'number': 482}</td>
#       <td>{'precision': 0.8152173913043478, 'recall': 0.9493670886075949, 'f1': 0.8771929824561402, 'number': 79}</td>
#       <td>{'precision': 0.5, 'recall': 0.5, 'f1': 0.5, 'number': 2}</td>
#       <td>{'precision': 0.9467966573816156, 'recall': 0.9518342201064127, 'f1': 0.9493087557603687, 'number': 3571}</td>
#       <td>{'precision': 0.8915304606240714, 'recall': 0.9331259720062208, 'f1': 0.9118541033434652, 'number': 643}</td>
#       <td>{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}</td>
#       <td>{'precision': 0.7605633802816901, 'recall': 0.9152542372881356, 'f1': 0.8307692307692307, 'number': 59}</td>
#       <td>{'precision': 0.4, 'recall': 0.6666666666666666, 'f1': 0.5, 'number': 3}</td>
#       <td>{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1}</td>
#       <td>{'precision': 0.6451612903225806, 'recall': 0.5714285714285714, 'f1': 0.606060606060606, 'number': 35}</td>
#       <td>0.942354</td>
#       <td>0.955385</td>
#       <td>0.948825</td>
#       <td>0.973156</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.048600</td>
#       <td>0.105450</td>
#       <td>{'precision': 0.9448818897637795, 'recall': 1.0, 'f1': 0.97165991902834, 'number': 120}</td>
#       <td>{'precision': 0.9325842696629213, 'recall': 0.9267990074441688, 'f1': 0.9296826384567517, 'number': 806}</td>
#       <td>{'precision': 0.6862745098039216, 'recall': 0.8974358974358975, 'f1': 0.7777777777777778, 'number': 39}</td>
#       <td>{'precision': 0.9737394957983193, 'recall': 0.9716981132075472, 'f1': 0.9727177334732424, 'number': 954}</td>
#       <td>{'precision': 0.9690095846645368, 'recall': 0.9749276759884281, 'f1': 0.9719596218554718, 'number': 3111}</td>
#       <td>{'precision': 0.9795081967213115, 'recall': 0.991701244813278, 'f1': 0.9855670103092784, 'number': 482}</td>
#       <td>{'precision': 0.8780487804878049, 'recall': 0.9113924050632911, 'f1': 0.8944099378881988, 'number': 79}</td>
#       <td>{'precision': 0.5, 'recall': 0.5, 'f1': 0.5, 'number': 2}</td>
#       <td>{'precision': 0.9533462926964732, 'recall': 0.9613553626435172, 'f1': 0.9573340769659788, 'number': 3571}</td>
#       <td>{'precision': 0.9216589861751152, 'recall': 0.9331259720062208, 'f1': 0.9273570324574961, 'number': 643}</td>
#       <td>{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}</td>
#       <td>{'precision': 0.8888888888888888, 'recall': 0.9491525423728814, 'f1': 0.9180327868852458, 'number': 59}</td>
#       <td>{'precision': 0.25, 'recall': 0.6666666666666666, 'f1': 0.36363636363636365, 'number': 3}</td>
#       <td>{'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 1}</td>
#       <td>{'precision': 0.75, 'recall': 0.7714285714285715, 'f1': 0.7605633802816902, 'number': 35}</td>
#       <td>0.953868</td>
#       <td>0.962148</td>
#       <td>0.957990</td>
#       <td>0.976953</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.016700</td>
#       <td>0.106426</td>
#       <td>{'precision': 0.9754098360655737, 'recall': 0.9916666666666667, 'f1': 0.9834710743801653, 'number': 120}</td>
#       <td>{'precision': 0.9385964912280702, 'recall': 0.9292803970223326, 'f1': 0.9339152119700748, 'number': 806}</td>
#       <td>{'precision': 0.7659574468085106, 'recall': 0.9230769230769231, 'f1': 0.8372093023255814, 'number': 39}</td>
#       <td>{'precision': 0.9708029197080292, 'recall': 0.9758909853249476, 'f1': 0.9733403031887089, 'number': 954}</td>
#       <td>{'precision': 0.9681630054122891, 'recall': 0.9774991963998714, 'f1': 0.972808701215611, 'number': 3111}</td>
#       <td>{'precision': 0.987603305785124, 'recall': 0.991701244813278, 'f1': 0.9896480331262941, 'number': 482}</td>
#       <td>{'precision': 0.8658536585365854, 'recall': 0.8987341772151899, 'f1': 0.8819875776397516, 'number': 79}</td>
#       <td>{'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 2}</td>
#       <td>{'precision': 0.9579855314412911, 'recall': 0.9641556986838421, 'f1': 0.9610607117934404, 'number': 3571}</td>
#       <td>{'precision': 0.9395866454689984, 'recall': 0.9191290824261276, 'f1': 0.9292452830188679, 'number': 643}</td>
#       <td>{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}</td>
#       <td>{'precision': 0.875, 'recall': 0.9491525423728814, 'f1': 0.9105691056910569, 'number': 59}</td>
#       <td>{'precision': 0.25, 'recall': 0.6666666666666666, 'f1': 0.36363636363636365, 'number': 3}</td>
#       <td>{'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 1}</td>
#       <td>{'precision': 0.7567567567567568, 'recall': 0.8, 'f1': 0.7777777777777778, 'number': 35}</td>
#       <td>0.957865</td>
#       <td>0.963763</td>
#       <td>0.960805</td>
#       <td>0.978351</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NOUN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NUM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VERB seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PROPN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: DET seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADV seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: CCONJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PUNCT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: INTJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: X seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: CONJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: SYM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PRT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trainer is attempting to log a value of "{'precision': 0.90625, 'recall': 0.9666666666666667, 'f1': 0.9354838709677419, 'number': 120}" of type <class 'dict'> for key "eval/CONJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9276807980049875, 'recall': 0.9230769230769231, 'f1': 0.9253731343283582, 'number': 806}" of type <class 'dict'> for key "eval/DJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.6956521739130435, 'recall': 0.8205128205128205, 'f1': 0.7529411764705882, 'number': 39}" of type <class 'dict'> for key "eval/DP" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.959375, 'recall': 0.9654088050314465, 'f1': 0.9623824451410659, 'number': 954}" of type <class 'dict'> for key "eval/DV" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9587824984147115, 'recall': 0.9720347155255545, 'f1': 0.9653631284916201, 'number': 3111}" of type <class 'dict'> for key "eval/ERB" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9734693877551021, 'recall': 0.9896265560165975, 'f1': 0.9814814814814816, 'number': 482}" of type <class 'dict'> for key "eval/ET" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.8152173913043478, 'recall': 0.9493670886075949, 'f1': 0.8771929824561402, 'number': 79}" of type <class 'dict'> for key "eval/NTJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.5, 'recall': 0.5, 'f1': 0.5, 'number': 2}" of type <class 'dict'> for key "eval/ONJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9467966573816156, 'recall': 0.9518342201064127, 'f1': 0.9493087557603687, 'number': 3571}" of type <class 'dict'> for key "eval/OUN" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.8915304606240714, 'recall': 0.9331259720062208, 'f1': 0.9118541033434652, 'number': 643}" of type <class 'dict'> for key "eval/ROPN" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}" of type <class 'dict'> for key "eval/RT" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.7605633802816901, 'recall': 0.9152542372881356, 'f1': 0.8307692307692307, 'number': 59}" of type <class 'dict'> for key "eval/UM" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.4, 'recall': 0.6666666666666666, 'f1': 0.5, 'number': 3}" of type <class 'dict'> for key "eval/UNCT" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1}" of type <class 'dict'> for key "eval/YM" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.6451612903225806, 'recall': 0.5714285714285714, 'f1': 0.606060606060606, 'number': 35}" of type <class 'dict'> for key "eval/_" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NOUN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NUM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VERB seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PROPN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: DET seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADV seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: CCONJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PUNCT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: INTJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: X seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: CONJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: SYM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PRT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trainer is attempting to log a value of "{'precision': 0.9448818897637795, 'recall': 1.0, 'f1': 0.97165991902834, 'number': 120}" of type <class 'dict'> for key "eval/CONJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9325842696629213, 'recall': 0.9267990074441688, 'f1': 0.9296826384567517, 'number': 806}" of type <class 'dict'> for key "eval/DJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.6862745098039216, 'recall': 0.8974358974358975, 'f1': 0.7777777777777778, 'number': 39}" of type <class 'dict'> for key "eval/DP" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9737394957983193, 'recall': 0.9716981132075472, 'f1': 0.9727177334732424, 'number': 954}" of type <class 'dict'> for key "eval/DV" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9690095846645368, 'recall': 0.9749276759884281, 'f1': 0.9719596218554718, 'number': 3111}" of type <class 'dict'> for key "eval/ERB" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9795081967213115, 'recall': 0.991701244813278, 'f1': 0.9855670103092784, 'number': 482}" of type <class 'dict'> for key "eval/ET" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.8780487804878049, 'recall': 0.9113924050632911, 'f1': 0.8944099378881988, 'number': 79}" of type <class 'dict'> for key "eval/NTJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.5, 'recall': 0.5, 'f1': 0.5, 'number': 2}" of type <class 'dict'> for key "eval/ONJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9533462926964732, 'recall': 0.9613553626435172, 'f1': 0.9573340769659788, 'number': 3571}" of type <class 'dict'> for key "eval/OUN" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9216589861751152, 'recall': 0.9331259720062208, 'f1': 0.9273570324574961, 'number': 643}" of type <class 'dict'> for key "eval/ROPN" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}" of type <class 'dict'> for key "eval/RT" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.8888888888888888, 'recall': 0.9491525423728814, 'f1': 0.9180327868852458, 'number': 59}" of type <class 'dict'> for key "eval/UM" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.25, 'recall': 0.6666666666666666, 'f1': 0.36363636363636365, 'number': 3}" of type <class 'dict'> for key "eval/UNCT" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 1}" of type <class 'dict'> for key "eval/YM" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.75, 'recall': 0.7714285714285715, 'f1': 0.7605633802816902, 'number': 35}" of type <class 'dict'> for key "eval/_" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NOUN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NUM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VERB seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PROPN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: DET seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADV seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: CCONJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PUNCT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: INTJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: X seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: CONJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: SYM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PRT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trainer is attempting to log a value of "{'precision': 0.9754098360655737, 'recall': 0.9916666666666667, 'f1': 0.9834710743801653, 'number': 120}" of type <class 'dict'> for key "eval/CONJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9385964912280702, 'recall': 0.9292803970223326, 'f1': 0.9339152119700748, 'number': 806}" of type <class 'dict'> for key "eval/DJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.7659574468085106, 'recall': 0.9230769230769231, 'f1': 0.8372093023255814, 'number': 39}" of type <class 'dict'> for key "eval/DP" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9708029197080292, 'recall': 0.9758909853249476, 'f1': 0.9733403031887089, 'number': 954}" of type <class 'dict'> for key "eval/DV" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9681630054122891, 'recall': 0.9774991963998714, 'f1': 0.972808701215611, 'number': 3111}" of type <class 'dict'> for key "eval/ERB" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.987603305785124, 'recall': 0.991701244813278, 'f1': 0.9896480331262941, 'number': 482}" of type <class 'dict'> for key "eval/ET" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.8658536585365854, 'recall': 0.8987341772151899, 'f1': 0.8819875776397516, 'number': 79}" of type <class 'dict'> for key "eval/NTJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 2}" of type <class 'dict'> for key "eval/ONJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9579855314412911, 'recall': 0.9641556986838421, 'f1': 0.9610607117934404, 'number': 3571}" of type <class 'dict'> for key "eval/OUN" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9395866454689984, 'recall': 0.9191290824261276, 'f1': 0.9292452830188679, 'number': 643}" of type <class 'dict'> for key "eval/ROPN" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}" of type <class 'dict'> for key "eval/RT" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.875, 'recall': 0.9491525423728814, 'f1': 0.9105691056910569, 'number': 59}" of type <class 'dict'> for key "eval/UM" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.25, 'recall': 0.6666666666666666, 'f1': 0.36363636363636365, 'number': 3}" of type <class 'dict'> for key "eval/UNCT" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 1}" of type <class 'dict'> for key "eval/YM" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.7567567567567568, 'recall': 0.8, 'f1': 0.7777777777777778, 'number': 35}" of type <class 'dict'> for key "eval/_" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# TrainOutput(global_step=3045, training_loss=0.08576998463992415, metrics={'train_runtime': 628.0811, 'train_samples_per_second': 77.512, 'train_steps_per_second': 4.848, 'total_flos': 1411352070483600.0, 'train_loss': 0.08576998463992415, 'epoch': 3.0})

# %%
trainer.evaluate()
# Out:
#     <div>
#
#       <progress value='89' max='89' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [89/89 00:04]
#     </div>
# Trainer is attempting to log a value of "{'precision': 0.9754098360655737, 'recall': 0.9916666666666667, 'f1': 0.9834710743801653, 'number': 120}" of type <class 'dict'> for key "eval/CONJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9385964912280702, 'recall': 0.9292803970223326, 'f1': 0.9339152119700748, 'number': 806}" of type <class 'dict'> for key "eval/DJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.7659574468085106, 'recall': 0.9230769230769231, 'f1': 0.8372093023255814, 'number': 39}" of type <class 'dict'> for key "eval/DP" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9708029197080292, 'recall': 0.9758909853249476, 'f1': 0.9733403031887089, 'number': 954}" of type <class 'dict'> for key "eval/DV" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9681630054122891, 'recall': 0.9774991963998714, 'f1': 0.972808701215611, 'number': 3111}" of type <class 'dict'> for key "eval/ERB" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.987603305785124, 'recall': 0.991701244813278, 'f1': 0.9896480331262941, 'number': 482}" of type <class 'dict'> for key "eval/ET" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.8658536585365854, 'recall': 0.8987341772151899, 'f1': 0.8819875776397516, 'number': 79}" of type <class 'dict'> for key "eval/NTJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 2}" of type <class 'dict'> for key "eval/ONJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9579855314412911, 'recall': 0.9641556986838421, 'f1': 0.9610607117934404, 'number': 3571}" of type <class 'dict'> for key "eval/OUN" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9395866454689984, 'recall': 0.9191290824261276, 'f1': 0.9292452830188679, 'number': 643}" of type <class 'dict'> for key "eval/ROPN" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}" of type <class 'dict'> for key "eval/RT" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.875, 'recall': 0.9491525423728814, 'f1': 0.9105691056910569, 'number': 59}" of type <class 'dict'> for key "eval/UM" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.25, 'recall': 0.6666666666666666, 'f1': 0.36363636363636365, 'number': 3}" of type <class 'dict'> for key "eval/UNCT" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 1}" of type <class 'dict'> for key "eval/YM" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.7567567567567568, 'recall': 0.8, 'f1': 0.7777777777777778, 'number': 35}" of type <class 'dict'> for key "eval/_" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# {'eval_loss': 0.10642596334218979,
#  'eval_CONJ': {'precision': 0.9754098360655737,
#   'recall': 0.9916666666666667,
#   'f1': 0.9834710743801653,
#   'number': 120},
#  'eval_DJ': {'precision': 0.9385964912280702,
#   'recall': 0.9292803970223326,
#   'f1': 0.9339152119700748,
#   'number': 806},
#  'eval_DP': {'precision': 0.7659574468085106,
#   'recall': 0.9230769230769231,
#   'f1': 0.8372093023255814,
#   'number': 39},
#  'eval_DV': {'precision': 0.9708029197080292,
#   'recall': 0.9758909853249476,
#   'f1': 0.9733403031887089,
#   'number': 954},
#  'eval_ERB': {'precision': 0.9681630054122891,
#   'recall': 0.9774991963998714,
#   'f1': 0.972808701215611,
#   'number': 3111},
#  'eval_ET': {'precision': 0.987603305785124,
#   'recall': 0.991701244813278,
#   'f1': 0.9896480331262941,
#   'number': 482},
#  'eval_NTJ': {'precision': 0.8658536585365854,
#   'recall': 0.8987341772151899,
#   'f1': 0.8819875776397516,
#   'number': 79},
#  'eval_ONJ': {'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 2},
#  'eval_OUN': {'precision': 0.9579855314412911,
#   'recall': 0.9641556986838421,
#   'f1': 0.9610607117934404,
#   'number': 3571},
#  'eval_ROPN': {'precision': 0.9395866454689984,
#   'recall': 0.9191290824261276,
#   'f1': 0.9292452830188679,
#   'number': 643},
#  'eval_RT': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2},
#  'eval_UM': {'precision': 0.875,
#   'recall': 0.9491525423728814,
#   'f1': 0.9105691056910569,
#   'number': 59},
#  'eval_UNCT': {'precision': 0.25,
#   'recall': 0.6666666666666666,
#   'f1': 0.36363636363636365,
#   'number': 3},
#  'eval_YM': {'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 1},
#  'eval__': {'precision': 0.7567567567567568,
#   'recall': 0.8,
#   'f1': 0.7777777777777778,
#   'number': 35},
#  'eval_overall_precision': 0.9578651685393258,
#  'eval_overall_recall': 0.963762995861512,
#  'eval_overall_f1': 0.9608050314465408,
#  'eval_overall_accuracy': 0.9783513738551207,
#  'eval_runtime': 5.3023,
#  'eval_samples_per_second': 267.429,
#  'eval_steps_per_second': 16.785,
#  'epoch': 3.0}

# %%
trainer.save_model('snunlp_KR-BERT-char16424.model')

# %%
# !tar cvfz snunlp_KR-BERT-char16424_v2.tar.gz snunlp_KR-BERT-char16424.model/
# Out:
# snunlp_KR-BERT-char16424.model/
# snunlp_KR-BERT-char16424.model/config.json
# snunlp_KR-BERT-char16424.model/training_args.bin
# snunlp_KR-BERT-char16424.model/pytorch_model.bin
# snunlp_KR-BERT-char16424.model/special_tokens_map.json
# snunlp_KR-BERT-char16424.model/tokenizer_config.json
# snunlp_KR-BERT-char16424.model/tokenizer.json
# snunlp_KR-BERT-char16424.model/vocab.txt

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# !mv snunlp_KR-BERT-char16424_v2.tar.gz  /content/drive/MyDrive/

# %%
# !rm -rf *.model test-pos *.gz

# %%
### ------- ### ------- ### ------- ### ------- ###
### klue/bert-base
###

# %%
model_checkpoint = "klue/bert-base"
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

train_tokenized_datasets = train_dataset.map(tokenize_and_align_labels, batched=True)
dev_tokenized_datasets = dev_dataset.map(tokenize_and_align_labels, batched=True)

model = AutoModelForTokenClassification.from_pretrained(model_checkpoint, num_labels=len(label_list))

args = TrainingArguments(
    f"test-{task}",
    evaluation_strategy = "epoch",
    learning_rate=1e-4,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=3,
    weight_decay=1e-5,
)

data_collator = DataCollatorForTokenClassification(tokenizer)
metric = load_metric("seqeval")


def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)

    true_predictions = [[label_list[p] for (p, l) in zip(prediction, label) if l != -100] for prediction, label in zip(predictions, labels)]
    true_labels = [[label_list[l] for (p, l) in zip(prediction, label) if l != -100] for prediction, label in zip(predictions, labels)]

    results = metric.compute(predictions=true_predictions, references=true_labels)
    return results
    
trainer = Trainer(
    model,
    args,
    train_dataset=train_tokenized_datasets,
    eval_dataset=dev_tokenized_datasets,
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)
trainer.train()
# Out:
# Map:   0%|          | 0/16228 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1418 [00:00<?, ? examples/s]
# Some weights of the model checkpoint at klue/bert-base were not used when initializing BertForTokenClassification: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at klue/bert-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.9/dist-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='3045' max='3045' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3045/3045 10:01, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Conj</th>
#       <th>Dj</th>
#       <th>Dp</th>
#       <th>Dv</th>
#       <th>Erb</th>
#       <th>Et</th>
#       <th>Ntj</th>
#       <th>Onj</th>
#       <th>Oun</th>
#       <th>Ropn</th>
#       <th>Rt</th>
#       <th>Um</th>
#       <th>Unct</th>
#       <th>Ym</th>
#       <th> </th>
#       <th>Overall Precision</th>
#       <th>Overall Recall</th>
#       <th>Overall F1</th>
#       <th>Overall Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.100800</td>
#       <td>0.105164</td>
#       <td>{'precision': 0.9375, 'recall': 1.0, 'f1': 0.967741935483871, 'number': 120}</td>
#       <td>{'precision': 0.9149453219927096, 'recall': 0.93424317617866, 'f1': 0.9244935543278083, 'number': 806}</td>
#       <td>{'precision': 0.7, 'recall': 0.717948717948718, 'f1': 0.708860759493671, 'number': 39}</td>
#       <td>{'precision': 0.9605809128630706, 'recall': 0.9706498951781971, 'f1': 0.9655891553701773, 'number': 954}</td>
#       <td>{'precision': 0.9609275730622617, 'recall': 0.9723561555769848, 'f1': 0.9666080843585237, 'number': 3111}</td>
#       <td>{'precision': 0.9876543209876543, 'recall': 0.995850622406639, 'f1': 0.9917355371900826, 'number': 482}</td>
#       <td>{'precision': 0.7849462365591398, 'recall': 0.9240506329113924, 'f1': 0.8488372093023255, 'number': 79}</td>
#       <td>{'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 2}</td>
#       <td>{'precision': 0.9424360400444939, 'recall': 0.9490338840660879, 'f1': 0.9457234547230361, 'number': 3571}</td>
#       <td>{'precision': 0.8810572687224669, 'recall': 0.9331259720062208, 'f1': 0.9063444108761329, 'number': 643}</td>
#       <td>{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}</td>
#       <td>{'precision': 0.7586206896551724, 'recall': 0.7457627118644068, 'f1': 0.752136752136752, 'number': 59}</td>
#       <td>{'precision': 0.25, 'recall': 0.6666666666666666, 'f1': 0.36363636363636365, 'number': 3}</td>
#       <td>{'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 1}</td>
#       <td>{'precision': 0.7941176470588235, 'recall': 0.7714285714285715, 'f1': 0.782608695652174, 'number': 35}</td>
#       <td>0.941165</td>
#       <td>0.955890</td>
#       <td>0.948470</td>
#       <td>0.971568</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.045400</td>
#       <td>0.090506</td>
#       <td>{'precision': 0.9596774193548387, 'recall': 0.9916666666666667, 'f1': 0.9754098360655739, 'number': 120}</td>
#       <td>{'precision': 0.9507575757575758, 'recall': 0.93424317617866, 'f1': 0.9424280350438049, 'number': 806}</td>
#       <td>{'precision': 0.6666666666666666, 'recall': 0.717948717948718, 'f1': 0.691358024691358, 'number': 39}</td>
#       <td>{'precision': 0.9676746611053181, 'recall': 0.9727463312368972, 'f1': 0.9702038682697334, 'number': 954}</td>
#       <td>{'precision': 0.9744735162731334, 'recall': 0.9816779170684667, 'f1': 0.9780624499599679, 'number': 3111}</td>
#       <td>{'precision': 0.9876288659793815, 'recall': 0.9937759336099585, 'f1': 0.9906928645294726, 'number': 482}</td>
#       <td>{'precision': 0.8690476190476191, 'recall': 0.9240506329113924, 'f1': 0.8957055214723927, 'number': 79}</td>
#       <td>{'precision': 0.5, 'recall': 0.5, 'f1': 0.5, 'number': 2}</td>
#       <td>{'precision': 0.9585765916041146, 'recall': 0.9655558667040045, 'f1': 0.9620535714285714, 'number': 3571}</td>
#       <td>{'precision': 0.9433962264150944, 'recall': 0.9331259720062208, 'f1': 0.9382329945269742, 'number': 643}</td>
#       <td>{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}</td>
#       <td>{'precision': 0.9032258064516129, 'recall': 0.9491525423728814, 'f1': 0.9256198347107438, 'number': 59}</td>
#       <td>{'precision': 0.2857142857142857, 'recall': 0.6666666666666666, 'f1': 0.4, 'number': 3}</td>
#       <td>{'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 1}</td>
#       <td>{'precision': 0.7272727272727273, 'recall': 0.9142857142857143, 'f1': 0.810126582278481, 'number': 35}</td>
#       <td>0.960377</td>
#       <td>0.966387</td>
#       <td>0.963373</td>
#       <td>0.980661</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.014800</td>
#       <td>0.096303</td>
#       <td>{'precision': 0.9523809523809523, 'recall': 1.0, 'f1': 0.975609756097561, 'number': 120}</td>
#       <td>{'precision': 0.9473023839397742, 'recall': 0.9367245657568238, 'f1': 0.9419837804117279, 'number': 806}</td>
#       <td>{'precision': 0.925, 'recall': 0.9487179487179487, 'f1': 0.9367088607594937, 'number': 39}</td>
#       <td>{'precision': 0.9739311783107404, 'recall': 0.9790356394129979, 'f1': 0.9764767381076842, 'number': 954}</td>
#       <td>{'precision': 0.97446536865624, 'recall': 0.9813564770170363, 'f1': 0.9778987828315182, 'number': 3111}</td>
#       <td>{'precision': 0.9876543209876543, 'recall': 0.995850622406639, 'f1': 0.9917355371900826, 'number': 482}</td>
#       <td>{'precision': 0.8690476190476191, 'recall': 0.9240506329113924, 'f1': 0.8957055214723927, 'number': 79}</td>
#       <td>{'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 2}</td>
#       <td>{'precision': 0.9596437517394935, 'recall': 0.9655558667040045, 'f1': 0.9625907314349526, 'number': 3571}</td>
#       <td>{'precision': 0.9404388714733543, 'recall': 0.9331259720062208, 'f1': 0.936768149882904, 'number': 643}</td>
#       <td>{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}</td>
#       <td>{'precision': 0.9180327868852459, 'recall': 0.9491525423728814, 'f1': 0.9333333333333333, 'number': 59}</td>
#       <td>{'precision': 0.2857142857142857, 'recall': 0.6666666666666666, 'f1': 0.4, 'number': 3}</td>
#       <td>{'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 1}</td>
#       <td>{'precision': 0.9705882352941176, 'recall': 0.9428571428571428, 'f1': 0.9565217391304348, 'number': 35}</td>
#       <td>0.963156</td>
#       <td>0.968406</td>
#       <td>0.965774</td>
#       <td>0.981306</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NOUN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NUM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VERB seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PROPN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: DET seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADV seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: CCONJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PUNCT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: INTJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: X seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: CONJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: SYM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PRT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trainer is attempting to log a value of "{'precision': 0.9375, 'recall': 1.0, 'f1': 0.967741935483871, 'number': 120}" of type <class 'dict'> for key "eval/CONJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9149453219927096, 'recall': 0.93424317617866, 'f1': 0.9244935543278083, 'number': 806}" of type <class 'dict'> for key "eval/DJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.7, 'recall': 0.717948717948718, 'f1': 0.708860759493671, 'number': 39}" of type <class 'dict'> for key "eval/DP" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9605809128630706, 'recall': 0.9706498951781971, 'f1': 0.9655891553701773, 'number': 954}" of type <class 'dict'> for key "eval/DV" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9609275730622617, 'recall': 0.9723561555769848, 'f1': 0.9666080843585237, 'number': 3111}" of type <class 'dict'> for key "eval/ERB" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9876543209876543, 'recall': 0.995850622406639, 'f1': 0.9917355371900826, 'number': 482}" of type <class 'dict'> for key "eval/ET" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.7849462365591398, 'recall': 0.9240506329113924, 'f1': 0.8488372093023255, 'number': 79}" of type <class 'dict'> for key "eval/NTJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 2}" of type <class 'dict'> for key "eval/ONJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9424360400444939, 'recall': 0.9490338840660879, 'f1': 0.9457234547230361, 'number': 3571}" of type <class 'dict'> for key "eval/OUN" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.8810572687224669, 'recall': 0.9331259720062208, 'f1': 0.9063444108761329, 'number': 643}" of type <class 'dict'> for key "eval/ROPN" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}" of type <class 'dict'> for key "eval/RT" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.7586206896551724, 'recall': 0.7457627118644068, 'f1': 0.752136752136752, 'number': 59}" of type <class 'dict'> for key "eval/UM" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.25, 'recall': 0.6666666666666666, 'f1': 0.36363636363636365, 'number': 3}" of type <class 'dict'> for key "eval/UNCT" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 1}" of type <class 'dict'> for key "eval/YM" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.7941176470588235, 'recall': 0.7714285714285715, 'f1': 0.782608695652174, 'number': 35}" of type <class 'dict'> for key "eval/_" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NOUN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NUM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VERB seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PROPN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: DET seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADV seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: CCONJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PUNCT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: INTJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: X seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: CONJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: SYM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PRT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trainer is attempting to log a value of "{'precision': 0.9596774193548387, 'recall': 0.9916666666666667, 'f1': 0.9754098360655739, 'number': 120}" of type <class 'dict'> for key "eval/CONJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9507575757575758, 'recall': 0.93424317617866, 'f1': 0.9424280350438049, 'number': 806}" of type <class 'dict'> for key "eval/DJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.6666666666666666, 'recall': 0.717948717948718, 'f1': 0.691358024691358, 'number': 39}" of type <class 'dict'> for key "eval/DP" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9676746611053181, 'recall': 0.9727463312368972, 'f1': 0.9702038682697334, 'number': 954}" of type <class 'dict'> for key "eval/DV" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9744735162731334, 'recall': 0.9816779170684667, 'f1': 0.9780624499599679, 'number': 3111}" of type <class 'dict'> for key "eval/ERB" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9876288659793815, 'recall': 0.9937759336099585, 'f1': 0.9906928645294726, 'number': 482}" of type <class 'dict'> for key "eval/ET" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.8690476190476191, 'recall': 0.9240506329113924, 'f1': 0.8957055214723927, 'number': 79}" of type <class 'dict'> for key "eval/NTJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.5, 'recall': 0.5, 'f1': 0.5, 'number': 2}" of type <class 'dict'> for key "eval/ONJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9585765916041146, 'recall': 0.9655558667040045, 'f1': 0.9620535714285714, 'number': 3571}" of type <class 'dict'> for key "eval/OUN" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9433962264150944, 'recall': 0.9331259720062208, 'f1': 0.9382329945269742, 'number': 643}" of type <class 'dict'> for key "eval/ROPN" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}" of type <class 'dict'> for key "eval/RT" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9032258064516129, 'recall': 0.9491525423728814, 'f1': 0.9256198347107438, 'number': 59}" of type <class 'dict'> for key "eval/UM" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.2857142857142857, 'recall': 0.6666666666666666, 'f1': 0.4, 'number': 3}" of type <class 'dict'> for key "eval/UNCT" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 1}" of type <class 'dict'> for key "eval/YM" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.7272727272727273, 'recall': 0.9142857142857143, 'f1': 0.810126582278481, 'number': 35}" of type <class 'dict'> for key "eval/_" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NOUN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NUM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VERB seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PROPN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: DET seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADV seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: CCONJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PUNCT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: INTJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: X seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: CONJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: SYM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PRT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trainer is attempting to log a value of "{'precision': 0.9523809523809523, 'recall': 1.0, 'f1': 0.975609756097561, 'number': 120}" of type <class 'dict'> for key "eval/CONJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9473023839397742, 'recall': 0.9367245657568238, 'f1': 0.9419837804117279, 'number': 806}" of type <class 'dict'> for key "eval/DJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.925, 'recall': 0.9487179487179487, 'f1': 0.9367088607594937, 'number': 39}" of type <class 'dict'> for key "eval/DP" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9739311783107404, 'recall': 0.9790356394129979, 'f1': 0.9764767381076842, 'number': 954}" of type <class 'dict'> for key "eval/DV" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.97446536865624, 'recall': 0.9813564770170363, 'f1': 0.9778987828315182, 'number': 3111}" of type <class 'dict'> for key "eval/ERB" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9876543209876543, 'recall': 0.995850622406639, 'f1': 0.9917355371900826, 'number': 482}" of type <class 'dict'> for key "eval/ET" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.8690476190476191, 'recall': 0.9240506329113924, 'f1': 0.8957055214723927, 'number': 79}" of type <class 'dict'> for key "eval/NTJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 2}" of type <class 'dict'> for key "eval/ONJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9596437517394935, 'recall': 0.9655558667040045, 'f1': 0.9625907314349526, 'number': 3571}" of type <class 'dict'> for key "eval/OUN" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9404388714733543, 'recall': 0.9331259720062208, 'f1': 0.936768149882904, 'number': 643}" of type <class 'dict'> for key "eval/ROPN" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}" of type <class 'dict'> for key "eval/RT" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9180327868852459, 'recall': 0.9491525423728814, 'f1': 0.9333333333333333, 'number': 59}" of type <class 'dict'> for key "eval/UM" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.2857142857142857, 'recall': 0.6666666666666666, 'f1': 0.4, 'number': 3}" of type <class 'dict'> for key "eval/UNCT" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 1}" of type <class 'dict'> for key "eval/YM" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9705882352941176, 'recall': 0.9428571428571428, 'f1': 0.9565217391304348, 'number': 35}" of type <class 'dict'> for key "eval/_" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# TrainOutput(global_step=3045, training_loss=0.07127448175536784, metrics={'train_runtime': 601.3971, 'train_samples_per_second': 80.952, 'train_steps_per_second': 5.063, 'total_flos': 1377159004655280.0, 'train_loss': 0.07127448175536784, 'epoch': 3.0})

# %%
trainer.evaluate()
# Out:
#     <div>
#
#       <progress value='178' max='89' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [89/89 00:52]
#     </div>
# Trainer is attempting to log a value of "{'precision': 0.9523809523809523, 'recall': 1.0, 'f1': 0.975609756097561, 'number': 120}" of type <class 'dict'> for key "eval/CONJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9473023839397742, 'recall': 0.9367245657568238, 'f1': 0.9419837804117279, 'number': 806}" of type <class 'dict'> for key "eval/DJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.925, 'recall': 0.9487179487179487, 'f1': 0.9367088607594937, 'number': 39}" of type <class 'dict'> for key "eval/DP" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9739311783107404, 'recall': 0.9790356394129979, 'f1': 0.9764767381076842, 'number': 954}" of type <class 'dict'> for key "eval/DV" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.97446536865624, 'recall': 0.9813564770170363, 'f1': 0.9778987828315182, 'number': 3111}" of type <class 'dict'> for key "eval/ERB" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9876543209876543, 'recall': 0.995850622406639, 'f1': 0.9917355371900826, 'number': 482}" of type <class 'dict'> for key "eval/ET" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.8690476190476191, 'recall': 0.9240506329113924, 'f1': 0.8957055214723927, 'number': 79}" of type <class 'dict'> for key "eval/NTJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 2}" of type <class 'dict'> for key "eval/ONJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9596437517394935, 'recall': 0.9655558667040045, 'f1': 0.9625907314349526, 'number': 3571}" of type <class 'dict'> for key "eval/OUN" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9404388714733543, 'recall': 0.9331259720062208, 'f1': 0.936768149882904, 'number': 643}" of type <class 'dict'> for key "eval/ROPN" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}" of type <class 'dict'> for key "eval/RT" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9180327868852459, 'recall': 0.9491525423728814, 'f1': 0.9333333333333333, 'number': 59}" of type <class 'dict'> for key "eval/UM" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.2857142857142857, 'recall': 0.6666666666666666, 'f1': 0.4, 'number': 3}" of type <class 'dict'> for key "eval/UNCT" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 1}" of type <class 'dict'> for key "eval/YM" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9705882352941176, 'recall': 0.9428571428571428, 'f1': 0.9565217391304348, 'number': 35}" of type <class 'dict'> for key "eval/_" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# {'eval_loss': 0.09630344808101654,
#  'eval_CONJ': {'precision': 0.9523809523809523,
#   'recall': 1.0,
#   'f1': 0.975609756097561,
#   'number': 120},
#  'eval_DJ': {'precision': 0.9473023839397742,
#   'recall': 0.9367245657568238,
#   'f1': 0.9419837804117279,
#   'number': 806},
#  'eval_DP': {'precision': 0.925,
#   'recall': 0.9487179487179487,
#   'f1': 0.9367088607594937,
#   'number': 39},
#  'eval_DV': {'precision': 0.9739311783107404,
#   'recall': 0.9790356394129979,
#   'f1': 0.9764767381076842,
#   'number': 954},
#  'eval_ERB': {'precision': 0.97446536865624,
#   'recall': 0.9813564770170363,
#   'f1': 0.9778987828315182,
#   'number': 3111},
#  'eval_ET': {'precision': 0.9876543209876543,
#   'recall': 0.995850622406639,
#   'f1': 0.9917355371900826,
#   'number': 482},
#  'eval_NTJ': {'precision': 0.8690476190476191,
#   'recall': 0.9240506329113924,
#   'f1': 0.8957055214723927,
#   'number': 79},
#  'eval_ONJ': {'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 2},
#  'eval_OUN': {'precision': 0.9596437517394935,
#   'recall': 0.9655558667040045,
#   'f1': 0.9625907314349526,
#   'number': 3571},
#  'eval_ROPN': {'precision': 0.9404388714733543,
#   'recall': 0.9331259720062208,
#   'f1': 0.936768149882904,
#   'number': 643},
#  'eval_RT': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2},
#  'eval_UM': {'precision': 0.9180327868852459,
#   'recall': 0.9491525423728814,
#   'f1': 0.9333333333333333,
#   'number': 59},
#  'eval_UNCT': {'precision': 0.2857142857142857,
#   'recall': 0.6666666666666666,
#   'f1': 0.4,
#   'number': 3},
#  'eval_YM': {'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 1},
#  'eval__': {'precision': 0.9705882352941176,
#   'recall': 0.9428571428571428,
#   'f1': 0.9565217391304348,
#   'number': 35},
#  'eval_overall_precision': 0.9631563096074691,
#  'eval_overall_recall': 0.9684061774502877,
#  'eval_overall_f1': 0.9657741091201932,
#  'eval_overall_accuracy': 0.981305557440456,
#  'eval_runtime': 10.0059,
#  'eval_samples_per_second': 141.717,
#  'eval_steps_per_second': 8.895,
#  'epoch': 3.0}

# %%
trainer.save_model('klue_bert-base.model')
# !tar cvfz klue_bert-base_v2.tar.gz klue_bert-base.model/
# !mv klue_bert-base_v2.tar.gz  /content/drive/MyDrive/
# Out:
#     <div>
#
#       <progress value='89' max='89' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [89/89 00:04]
#     </div>
# Trainer is attempting to log a value of "{'precision': 0.9523809523809523, 'recall': 1.0, 'f1': 0.975609756097561, 'number': 120}" of type <class 'dict'> for key "eval/CONJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9473023839397742, 'recall': 0.9367245657568238, 'f1': 0.9419837804117279, 'number': 806}" of type <class 'dict'> for key "eval/DJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.925, 'recall': 0.9487179487179487, 'f1': 0.9367088607594937, 'number': 39}" of type <class 'dict'> for key "eval/DP" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9739311783107404, 'recall': 0.9790356394129979, 'f1': 0.9764767381076842, 'number': 954}" of type <class 'dict'> for key "eval/DV" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.97446536865624, 'recall': 0.9813564770170363, 'f1': 0.9778987828315182, 'number': 3111}" of type <class 'dict'> for key "eval/ERB" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9876543209876543, 'recall': 0.995850622406639, 'f1': 0.9917355371900826, 'number': 482}" of type <class 'dict'> for key "eval/ET" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.8690476190476191, 'recall': 0.9240506329113924, 'f1': 0.8957055214723927, 'number': 79}" of type <class 'dict'> for key "eval/NTJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 2}" of type <class 'dict'> for key "eval/ONJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9596437517394935, 'recall': 0.9655558667040045, 'f1': 0.9625907314349526, 'number': 3571}" of type <class 'dict'> for key "eval/OUN" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9404388714733543, 'recall': 0.9331259720062208, 'f1': 0.936768149882904, 'number': 643}" of type <class 'dict'> for key "eval/ROPN" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}" of type <class 'dict'> for key "eval/RT" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9180327868852459, 'recall': 0.9491525423728814, 'f1': 0.9333333333333333, 'number': 59}" of type <class 'dict'> for key "eval/UM" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.2857142857142857, 'recall': 0.6666666666666666, 'f1': 0.4, 'number': 3}" of type <class 'dict'> for key "eval/UNCT" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 1}" of type <class 'dict'> for key "eval/YM" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9705882352941176, 'recall': 0.9428571428571428, 'f1': 0.9565217391304348, 'number': 35}" of type <class 'dict'> for key "eval/_" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# klue_bert-base.model/
# klue_bert-base.model/config.json
# klue_bert-base.model/training_args.bin
# klue_bert-base.model/pytorch_model.bin
# klue_bert-base.model/special_tokens_map.json
# klue_bert-base.model/tokenizer_config.json
# klue_bert-base.model/tokenizer.json
# klue_bert-base.model/vocab.txt

# %%
### ------- ### ------- ### ------- ### ------- ###
### koelectra-base-v3
###

# %%
model_checkpoint = "monologg/koelectra-base-v3-discriminator"
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

train_tokenized_datasets = train_dataset.map(tokenize_and_align_labels, batched=True)
dev_tokenized_datasets = dev_dataset.map(tokenize_and_align_labels, batched=True)

model = AutoModelForTokenClassification.from_pretrained(model_checkpoint, num_labels=len(label_list))

args = TrainingArguments(
    f"test-{task}",
    evaluation_strategy = "epoch",
    learning_rate=1e-4,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=3,
    weight_decay=1e-5,
)

data_collator = DataCollatorForTokenClassification(tokenizer)
metric = load_metric("seqeval")


def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)

    true_predictions = [[label_list[p] for (p, l) in zip(prediction, label) if l != -100] for prediction, label in zip(predictions, labels)]
    true_labels = [[label_list[l] for (p, l) in zip(prediction, label) if l != -100] for prediction, label in zip(predictions, labels)]

    results = metric.compute(predictions=true_predictions, references=true_labels)
    return results
    
trainer = Trainer(
    model,
    args,
    train_dataset=train_tokenized_datasets,
    eval_dataset=dev_tokenized_datasets,
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)


trainer.train()
trainer.evaluate()
# Out:
# Map:   0%|          | 0/16228 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1418 [00:00<?, ? examples/s]
# Some weights of the model checkpoint at monologg/koelectra-base-v3-discriminator were not used when initializing ElectraForTokenClassification: ['discriminator_predictions.dense_prediction.bias', 'discriminator_predictions.dense.weight', 'discriminator_predictions.dense_prediction.weight', 'discriminator_predictions.dense.bias']
# - This IS expected if you are initializing ElectraForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ElectraForTokenClassification were not initialized from the model checkpoint at monologg/koelectra-base-v3-discriminator and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.9/dist-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# You're using a ElectraTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='3045' max='3045' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3045/3045 10:07, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Conj</th>
#       <th>Dj</th>
#       <th>Dp</th>
#       <th>Dv</th>
#       <th>Erb</th>
#       <th>Et</th>
#       <th>Ntj</th>
#       <th>Onj</th>
#       <th>Oun</th>
#       <th>Ropn</th>
#       <th>Rt</th>
#       <th>Um</th>
#       <th>Unct</th>
#       <th>Ym</th>
#       <th> </th>
#       <th>Overall Precision</th>
#       <th>Overall Recall</th>
#       <th>Overall F1</th>
#       <th>Overall Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.100100</td>
#       <td>0.091012</td>
#       <td>{'precision': 0.937007874015748, 'recall': 0.9916666666666667, 'f1': 0.9635627530364372, 'number': 120}</td>
#       <td>{'precision': 0.942643391521197, 'recall': 0.9379652605459057, 'f1': 0.9402985074626866, 'number': 806}</td>
#       <td>{'precision': 0.574468085106383, 'recall': 0.6923076923076923, 'f1': 0.627906976744186, 'number': 39}</td>
#       <td>{'precision': 0.9648397104446742, 'recall': 0.9779874213836478, 'f1': 0.9713690786048933, 'number': 954}</td>
#       <td>{'precision': 0.96844118584635, 'recall': 0.9765348762455802, 'f1': 0.9724711907810498, 'number': 3111}</td>
#       <td>{'precision': 0.9876796714579056, 'recall': 0.9979253112033195, 'f1': 0.9927760577915377, 'number': 482}</td>
#       <td>{'precision': 0.8604651162790697, 'recall': 0.9367088607594937, 'f1': 0.8969696969696971, 'number': 79}</td>
#       <td>{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}</td>
#       <td>{'precision': 0.958728388176241, 'recall': 0.9627555306636797, 'f1': 0.9607377392762331, 'number': 3571}</td>
#       <td>{'precision': 0.9430379746835443, 'recall': 0.926905132192846, 'f1': 0.9349019607843138, 'number': 643}</td>
#       <td>{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}</td>
#       <td>{'precision': 0.8382352941176471, 'recall': 0.9661016949152542, 'f1': 0.8976377952755905, 'number': 59}</td>
#       <td>{'precision': 0.14285714285714285, 'recall': 0.3333333333333333, 'f1': 0.2, 'number': 3}</td>
#       <td>{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1}</td>
#       <td>{'precision': 0.55, 'recall': 0.6285714285714286, 'f1': 0.5866666666666667, 'number': 35}</td>
#       <td>0.955346</td>
#       <td>0.963157</td>
#       <td>0.959236</td>
#       <td>0.978391</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.047500</td>
#       <td>0.086577</td>
#       <td>{'precision': 0.975609756097561, 'recall': 1.0, 'f1': 0.9876543209876543, 'number': 120}</td>
#       <td>{'precision': 0.9519595448798989, 'recall': 0.93424317617866, 'f1': 0.9430181590482153, 'number': 806}</td>
#       <td>{'precision': 0.8780487804878049, 'recall': 0.9230769230769231, 'f1': 0.9, 'number': 39}</td>
#       <td>{'precision': 0.9700413223140496, 'recall': 0.9842767295597484, 'f1': 0.9771071800208118, 'number': 954}</td>
#       <td>{'precision': 0.9744408945686901, 'recall': 0.9803921568627451, 'f1': 0.977407466752123, 'number': 3111}</td>
#       <td>{'precision': 0.985655737704918, 'recall': 0.9979253112033195, 'f1': 0.9917525773195875, 'number': 482}</td>
#       <td>{'precision': 0.9024390243902439, 'recall': 0.9367088607594937, 'f1': 0.9192546583850932, 'number': 79}</td>
#       <td>{'precision': 0.6666666666666666, 'recall': 1.0, 'f1': 0.8, 'number': 2}</td>
#       <td>{'precision': 0.967606813739179, 'recall': 0.9703164379725567, 'f1': 0.9689597315436241, 'number': 3571}</td>
#       <td>{'precision': 0.9533762057877814, 'recall': 0.9222395023328149, 'f1': 0.9375494071146245, 'number': 643}</td>
#       <td>{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}</td>
#       <td>{'precision': 0.9180327868852459, 'recall': 0.9491525423728814, 'f1': 0.9333333333333333, 'number': 59}</td>
#       <td>{'precision': 0.3333333333333333, 'recall': 0.3333333333333333, 'f1': 0.3333333333333333, 'number': 3}</td>
#       <td>{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1}</td>
#       <td>{'precision': 0.8333333333333334, 'recall': 0.8571428571428571, 'f1': 0.8450704225352113, 'number': 35}</td>
#       <td>0.966865</td>
#       <td>0.969012</td>
#       <td>0.967937</td>
#       <td>0.981511</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.018300</td>
#       <td>0.078612</td>
#       <td>{'precision': 0.975609756097561, 'recall': 1.0, 'f1': 0.9876543209876543, 'number': 120}</td>
#       <td>{'precision': 0.9584382871536524, 'recall': 0.9441687344913151, 'f1': 0.95125, 'number': 806}</td>
#       <td>{'precision': 0.8372093023255814, 'recall': 0.9230769230769231, 'f1': 0.878048780487805, 'number': 39}</td>
#       <td>{'precision': 0.9780564263322884, 'recall': 0.9811320754716981, 'f1': 0.9795918367346939, 'number': 954}</td>
#       <td>{'precision': 0.9772872680742163, 'recall': 0.9819993571198972, 'f1': 0.9796376463043129, 'number': 3111}</td>
#       <td>{'precision': 0.985655737704918, 'recall': 0.9979253112033195, 'f1': 0.9917525773195875, 'number': 482}</td>
#       <td>{'precision': 0.8020833333333334, 'recall': 0.9746835443037974, 'f1': 0.88, 'number': 79}</td>
#       <td>{'precision': 0.6666666666666666, 'recall': 1.0, 'f1': 0.8, 'number': 2}</td>
#       <td>{'precision': 0.9693080357142857, 'recall': 0.972836740408849, 'f1': 0.971069182389937, 'number': 3571}</td>
#       <td>{'precision': 0.9538950715421304, 'recall': 0.9331259720062208, 'f1': 0.9433962264150944, 'number': 643}</td>
#       <td>{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}</td>
#       <td>{'precision': 0.9193548387096774, 'recall': 0.9661016949152542, 'f1': 0.9421487603305785, 'number': 59}</td>
#       <td>{'precision': 0.2857142857142857, 'recall': 0.6666666666666666, 'f1': 0.4, 'number': 3}</td>
#       <td>{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1}</td>
#       <td>{'precision': 0.8333333333333334, 'recall': 0.8571428571428571, 'f1': 0.8450704225352113, 'number': 35}</td>
#       <td>0.968134</td>
#       <td>0.972141</td>
#       <td>0.970133</td>
#       <td>0.983290</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NOUN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NUM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VERB seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PROPN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: DET seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADV seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: CCONJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PUNCT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: INTJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: X seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: CONJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: SYM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PRT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trainer is attempting to log a value of "{'precision': 0.937007874015748, 'recall': 0.9916666666666667, 'f1': 0.9635627530364372, 'number': 120}" of type <class 'dict'> for key "eval/CONJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.942643391521197, 'recall': 0.9379652605459057, 'f1': 0.9402985074626866, 'number': 806}" of type <class 'dict'> for key "eval/DJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.574468085106383, 'recall': 0.6923076923076923, 'f1': 0.627906976744186, 'number': 39}" of type <class 'dict'> for key "eval/DP" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9648397104446742, 'recall': 0.9779874213836478, 'f1': 0.9713690786048933, 'number': 954}" of type <class 'dict'> for key "eval/DV" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.96844118584635, 'recall': 0.9765348762455802, 'f1': 0.9724711907810498, 'number': 3111}" of type <class 'dict'> for key "eval/ERB" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9876796714579056, 'recall': 0.9979253112033195, 'f1': 0.9927760577915377, 'number': 482}" of type <class 'dict'> for key "eval/ET" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.8604651162790697, 'recall': 0.9367088607594937, 'f1': 0.8969696969696971, 'number': 79}" of type <class 'dict'> for key "eval/NTJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}" of type <class 'dict'> for key "eval/ONJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.958728388176241, 'recall': 0.9627555306636797, 'f1': 0.9607377392762331, 'number': 3571}" of type <class 'dict'> for key "eval/OUN" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9430379746835443, 'recall': 0.926905132192846, 'f1': 0.9349019607843138, 'number': 643}" of type <class 'dict'> for key "eval/ROPN" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}" of type <class 'dict'> for key "eval/RT" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.8382352941176471, 'recall': 0.9661016949152542, 'f1': 0.8976377952755905, 'number': 59}" of type <class 'dict'> for key "eval/UM" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.14285714285714285, 'recall': 0.3333333333333333, 'f1': 0.2, 'number': 3}" of type <class 'dict'> for key "eval/UNCT" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1}" of type <class 'dict'> for key "eval/YM" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.55, 'recall': 0.6285714285714286, 'f1': 0.5866666666666667, 'number': 35}" of type <class 'dict'> for key "eval/_" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NOUN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NUM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VERB seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PROPN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: DET seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADV seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: CCONJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PUNCT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: INTJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: X seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: CONJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: SYM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PRT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trainer is attempting to log a value of "{'precision': 0.975609756097561, 'recall': 1.0, 'f1': 0.9876543209876543, 'number': 120}" of type <class 'dict'> for key "eval/CONJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9519595448798989, 'recall': 0.93424317617866, 'f1': 0.9430181590482153, 'number': 806}" of type <class 'dict'> for key "eval/DJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.8780487804878049, 'recall': 0.9230769230769231, 'f1': 0.9, 'number': 39}" of type <class 'dict'> for key "eval/DP" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9700413223140496, 'recall': 0.9842767295597484, 'f1': 0.9771071800208118, 'number': 954}" of type <class 'dict'> for key "eval/DV" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9744408945686901, 'recall': 0.9803921568627451, 'f1': 0.977407466752123, 'number': 3111}" of type <class 'dict'> for key "eval/ERB" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.985655737704918, 'recall': 0.9979253112033195, 'f1': 0.9917525773195875, 'number': 482}" of type <class 'dict'> for key "eval/ET" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9024390243902439, 'recall': 0.9367088607594937, 'f1': 0.9192546583850932, 'number': 79}" of type <class 'dict'> for key "eval/NTJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.6666666666666666, 'recall': 1.0, 'f1': 0.8, 'number': 2}" of type <class 'dict'> for key "eval/ONJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.967606813739179, 'recall': 0.9703164379725567, 'f1': 0.9689597315436241, 'number': 3571}" of type <class 'dict'> for key "eval/OUN" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9533762057877814, 'recall': 0.9222395023328149, 'f1': 0.9375494071146245, 'number': 643}" of type <class 'dict'> for key "eval/ROPN" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}" of type <class 'dict'> for key "eval/RT" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9180327868852459, 'recall': 0.9491525423728814, 'f1': 0.9333333333333333, 'number': 59}" of type <class 'dict'> for key "eval/UM" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.3333333333333333, 'recall': 0.3333333333333333, 'f1': 0.3333333333333333, 'number': 3}" of type <class 'dict'> for key "eval/UNCT" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1}" of type <class 'dict'> for key "eval/YM" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.8333333333333334, 'recall': 0.8571428571428571, 'f1': 0.8450704225352113, 'number': 35}" of type <class 'dict'> for key "eval/_" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NOUN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NUM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VERB seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PROPN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: DET seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADV seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: CCONJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PUNCT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: INTJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: X seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: CONJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: SYM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PRT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trainer is attempting to log a value of "{'precision': 0.975609756097561, 'recall': 1.0, 'f1': 0.9876543209876543, 'number': 120}" of type <class 'dict'> for key "eval/CONJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9584382871536524, 'recall': 0.9441687344913151, 'f1': 0.95125, 'number': 806}" of type <class 'dict'> for key "eval/DJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.8372093023255814, 'recall': 0.9230769230769231, 'f1': 0.878048780487805, 'number': 39}" of type <class 'dict'> for key "eval/DP" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9780564263322884, 'recall': 0.9811320754716981, 'f1': 0.9795918367346939, 'number': 954}" of type <class 'dict'> for key "eval/DV" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9772872680742163, 'recall': 0.9819993571198972, 'f1': 0.9796376463043129, 'number': 3111}" of type <class 'dict'> for key "eval/ERB" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.985655737704918, 'recall': 0.9979253112033195, 'f1': 0.9917525773195875, 'number': 482}" of type <class 'dict'> for key "eval/ET" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.8020833333333334, 'recall': 0.9746835443037974, 'f1': 0.88, 'number': 79}" of type <class 'dict'> for key "eval/NTJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.6666666666666666, 'recall': 1.0, 'f1': 0.8, 'number': 2}" of type <class 'dict'> for key "eval/ONJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9693080357142857, 'recall': 0.972836740408849, 'f1': 0.971069182389937, 'number': 3571}" of type <class 'dict'> for key "eval/OUN" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9538950715421304, 'recall': 0.9331259720062208, 'f1': 0.9433962264150944, 'number': 643}" of type <class 'dict'> for key "eval/ROPN" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}" of type <class 'dict'> for key "eval/RT" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9193548387096774, 'recall': 0.9661016949152542, 'f1': 0.9421487603305785, 'number': 59}" of type <class 'dict'> for key "eval/UM" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.2857142857142857, 'recall': 0.6666666666666666, 'f1': 0.4, 'number': 3}" of type <class 'dict'> for key "eval/UNCT" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1}" of type <class 'dict'> for key "eval/YM" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.8333333333333334, 'recall': 0.8571428571428571, 'f1': 0.8450704225352113, 'number': 35}" of type <class 'dict'> for key "eval/_" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
#     <div>
#
#       <progress value='89' max='89' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [89/89 00:04]
#     </div>
# Trainer is attempting to log a value of "{'precision': 0.975609756097561, 'recall': 1.0, 'f1': 0.9876543209876543, 'number': 120}" of type <class 'dict'> for key "eval/CONJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9584382871536524, 'recall': 0.9441687344913151, 'f1': 0.95125, 'number': 806}" of type <class 'dict'> for key "eval/DJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.8372093023255814, 'recall': 0.9230769230769231, 'f1': 0.878048780487805, 'number': 39}" of type <class 'dict'> for key "eval/DP" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9780564263322884, 'recall': 0.9811320754716981, 'f1': 0.9795918367346939, 'number': 954}" of type <class 'dict'> for key "eval/DV" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9772872680742163, 'recall': 0.9819993571198972, 'f1': 0.9796376463043129, 'number': 3111}" of type <class 'dict'> for key "eval/ERB" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.985655737704918, 'recall': 0.9979253112033195, 'f1': 0.9917525773195875, 'number': 482}" of type <class 'dict'> for key "eval/ET" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.8020833333333334, 'recall': 0.9746835443037974, 'f1': 0.88, 'number': 79}" of type <class 'dict'> for key "eval/NTJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.6666666666666666, 'recall': 1.0, 'f1': 0.8, 'number': 2}" of type <class 'dict'> for key "eval/ONJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9693080357142857, 'recall': 0.972836740408849, 'f1': 0.971069182389937, 'number': 3571}" of type <class 'dict'> for key "eval/OUN" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9538950715421304, 'recall': 0.9331259720062208, 'f1': 0.9433962264150944, 'number': 643}" of type <class 'dict'> for key "eval/ROPN" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}" of type <class 'dict'> for key "eval/RT" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9193548387096774, 'recall': 0.9661016949152542, 'f1': 0.9421487603305785, 'number': 59}" of type <class 'dict'> for key "eval/UM" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.2857142857142857, 'recall': 0.6666666666666666, 'f1': 0.4, 'number': 3}" of type <class 'dict'> for key "eval/UNCT" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1}" of type <class 'dict'> for key "eval/YM" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.8333333333333334, 'recall': 0.8571428571428571, 'f1': 0.8450704225352113, 'number': 35}" of type <class 'dict'> for key "eval/_" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# {'eval_loss': 0.07861168682575226,
#  'eval_CONJ': {'precision': 0.975609756097561,
#   'recall': 1.0,
#   'f1': 0.9876543209876543,
#   'number': 120},
#  'eval_DJ': {'precision': 0.9584382871536524,
#   'recall': 0.9441687344913151,
#   'f1': 0.95125,
#   'number': 806},
#  'eval_DP': {'precision': 0.8372093023255814,
#   'recall': 0.9230769230769231,
#   'f1': 0.878048780487805,
#   'number': 39},
#  'eval_DV': {'precision': 0.9780564263322884,
#   'recall': 0.9811320754716981,
#   'f1': 0.9795918367346939,
#   'number': 954},
#  'eval_ERB': {'precision': 0.9772872680742163,
#   'recall': 0.9819993571198972,
#   'f1': 0.9796376463043129,
#   'number': 3111},
#  'eval_ET': {'precision': 0.985655737704918,
#   'recall': 0.9979253112033195,
#   'f1': 0.9917525773195875,
#   'number': 482},
#  'eval_NTJ': {'precision': 0.8020833333333334,
#   'recall': 0.9746835443037974,
#   'f1': 0.88,
#   'number': 79},
#  'eval_ONJ': {'precision': 0.6666666666666666,
#   'recall': 1.0,
#   'f1': 0.8,
#   'number': 2},
#  'eval_OUN': {'precision': 0.9693080357142857,
#   'recall': 0.972836740408849,
#   'f1': 0.971069182389937,
#   'number': 3571},
#  'eval_ROPN': {'precision': 0.9538950715421304,
#   'recall': 0.9331259720062208,
#   'f1': 0.9433962264150944,
#   'number': 643},
#  'eval_RT': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2},
#  'eval_UM': {'precision': 0.9193548387096774,
#   'recall': 0.9661016949152542,
#   'f1': 0.9421487603305785,
#   'number': 59},
#  'eval_UNCT': {'precision': 0.2857142857142857,
#   'recall': 0.6666666666666666,
#   'f1': 0.4,
#   'number': 3},
#  'eval_YM': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1},
#  'eval__': {'precision': 0.8333333333333334,
#   'recall': 0.8571428571428571,
#   'f1': 0.8450704225352113,
#   'number': 35},
#  'eval_overall_precision': 0.9681342983514274,
#  'eval_overall_recall': 0.9721409104673463,
#  'eval_overall_f1': 0.9701334676403929,
#  'eval_overall_accuracy': 0.983289712099859,
#  'eval_runtime': 5.3634,
#  'eval_samples_per_second': 264.385,
#  'eval_steps_per_second': 16.594,
#  'epoch': 3.0}

# %%
trainer.save_model('koelectra-base.model')
# !tar cvfz koelectra-base_v2.tar.gz koelectra-base.model/
# !mv koelectra-base_v2.tar.gz  /content/drive/MyDrive/
# Out:
# koelectra-base.model/
# koelectra-base.model/config.json
# koelectra-base.model/training_args.bin
# koelectra-base.model/pytorch_model.bin
# koelectra-base.model/special_tokens_map.json
# koelectra-base.model/tokenizer_config.json
# koelectra-base.model/tokenizer.json
# koelectra-base.model/vocab.txt

# %%
# !rm -rf *.model test-pos *.gz

# %%
# bert-base-multilingual-cased

model_checkpoint = "bert-base-multilingual-cased"
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

train_tokenized_datasets = train_dataset.map(tokenize_and_align_labels, batched=True)
dev_tokenized_datasets = dev_dataset.map(tokenize_and_align_labels, batched=True)

model = AutoModelForTokenClassification.from_pretrained(model_checkpoint, num_labels=len(label_list))

args = TrainingArguments(
    f"test-{task}",
    evaluation_strategy = "epoch",
    learning_rate=1e-4,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=3,
    weight_decay=1e-5,
)

data_collator = DataCollatorForTokenClassification(tokenizer)
metric = load_metric("seqeval")


def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)

    true_predictions = [[label_list[p] for (p, l) in zip(prediction, label) if l != -100] for prediction, label in zip(predictions, labels)]
    true_labels = [[label_list[l] for (p, l) in zip(prediction, label) if l != -100] for prediction, label in zip(predictions, labels)]

    results = metric.compute(predictions=true_predictions, references=true_labels)
    return results
    
trainer = Trainer(
    model,
    args,
    train_dataset=train_tokenized_datasets,
    eval_dataset=dev_tokenized_datasets,
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)


trainer.train()
trainer.evaluate()
# Out:
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# Map:   0%|          | 0/16228 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1418 [00:00<?, ? examples/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertForTokenClassification: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.9/dist-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='3045' max='3045' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3045/3045 13:05, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Conj</th>
#       <th>Dj</th>
#       <th>Dp</th>
#       <th>Dv</th>
#       <th>Erb</th>
#       <th>Et</th>
#       <th>Ntj</th>
#       <th>Onj</th>
#       <th>Oun</th>
#       <th>Ropn</th>
#       <th>Rt</th>
#       <th>Um</th>
#       <th>Unct</th>
#       <th>Ym</th>
#       <th> </th>
#       <th>Overall Precision</th>
#       <th>Overall Recall</th>
#       <th>Overall F1</th>
#       <th>Overall Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.191400</td>
#       <td>0.155804</td>
#       <td>{'precision': 0.9022556390977443, 'recall': 1.0, 'f1': 0.9486166007905138, 'number': 120}</td>
#       <td>{'precision': 0.9217506631299734, 'recall': 0.8622828784119106, 'f1': 0.891025641025641, 'number': 806}</td>
#       <td>{'precision': 0.575, 'recall': 0.5897435897435898, 'f1': 0.5822784810126582, 'number': 39}</td>
#       <td>{'precision': 0.894, 'recall': 0.9371069182389937, 'f1': 0.9150460593654043, 'number': 954}</td>
#       <td>{'precision': 0.9427100096556164, 'recall': 0.9414979106396657, 'f1': 0.9421035702798327, 'number': 3111}</td>
#       <td>{'precision': 0.967479674796748, 'recall': 0.9875518672199171, 'f1': 0.9774127310061602, 'number': 482}</td>
#       <td>{'precision': 0.8148148148148148, 'recall': 0.8354430379746836, 'f1': 0.825, 'number': 79}</td>
#       <td>{'precision': 1.0, 'recall': 0.5, 'f1': 0.6666666666666666, 'number': 2}</td>
#       <td>{'precision': 0.903486750348675, 'recall': 0.9070288434612154, 'f1': 0.9052543320290666, 'number': 3571}</td>
#       <td>{'precision': 0.810930576070901, 'recall': 0.8538102643856921, 'f1': 0.8318181818181819, 'number': 643}</td>
#       <td>{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}</td>
#       <td>{'precision': 0.7846153846153846, 'recall': 0.864406779661017, 'f1': 0.8225806451612904, 'number': 59}</td>
#       <td>{'precision': 0.2857142857142857, 'recall': 0.6666666666666666, 'f1': 0.4, 'number': 3}</td>
#       <td>{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1}</td>
#       <td>{'precision': 0.5142857142857142, 'recall': 0.5142857142857142, 'f1': 0.5142857142857142, 'number': 35}</td>
#       <td>0.908389</td>
#       <td>0.914808</td>
#       <td>0.911587</td>
#       <td>0.955474</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.100700</td>
#       <td>0.138596</td>
#       <td>{'precision': 0.9230769230769231, 'recall': 1.0, 'f1': 0.9600000000000001, 'number': 120}</td>
#       <td>{'precision': 0.8798017348203222, 'recall': 0.8808933002481389, 'f1': 0.8803471791692499, 'number': 806}</td>
#       <td>{'precision': 0.6744186046511628, 'recall': 0.7435897435897436, 'f1': 0.7073170731707318, 'number': 39}</td>
#       <td>{'precision': 0.9284232365145229, 'recall': 0.9381551362683438, 'f1': 0.9332638164754953, 'number': 954}</td>
#       <td>{'precision': 0.9460408684546615, 'recall': 0.9524268723882996, 'f1': 0.9492231299054942, 'number': 3111}</td>
#       <td>{'precision': 0.9754601226993865, 'recall': 0.9896265560165975, 'f1': 0.9824922760041194, 'number': 482}</td>
#       <td>{'precision': 0.8461538461538461, 'recall': 0.8354430379746836, 'f1': 0.840764331210191, 'number': 79}</td>
#       <td>{'precision': 1.0, 'recall': 0.5, 'f1': 0.6666666666666666, 'number': 2}</td>
#       <td>{'precision': 0.9219052893935198, 'recall': 0.9322318678241389, 'f1': 0.927039821776664, 'number': 3571}</td>
#       <td>{'precision': 0.8742138364779874, 'recall': 0.864696734059098, 'f1': 0.8694292415949961, 'number': 643}</td>
#       <td>{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}</td>
#       <td>{'precision': 0.859375, 'recall': 0.9322033898305084, 'f1': 0.8943089430894309, 'number': 59}</td>
#       <td>{'precision': 0.125, 'recall': 0.6666666666666666, 'f1': 0.21052631578947367, 'number': 3}</td>
#       <td>{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1}</td>
#       <td>{'precision': 0.6122448979591837, 'recall': 0.8571428571428571, 'f1': 0.7142857142857143, 'number': 35}</td>
#       <td>0.921457</td>
#       <td>0.931967</td>
#       <td>0.926682</td>
#       <td>0.963938</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.041700</td>
#       <td>0.125147</td>
#       <td>{'precision': 0.9448818897637795, 'recall': 1.0, 'f1': 0.97165991902834, 'number': 120}</td>
#       <td>{'precision': 0.9217948717948717, 'recall': 0.892059553349876, 'f1': 0.9066834804539723, 'number': 806}</td>
#       <td>{'precision': 0.9230769230769231, 'recall': 0.9230769230769231, 'f1': 0.9230769230769231, 'number': 39}</td>
#       <td>{'precision': 0.9460020768431984, 'recall': 0.9549266247379455, 'f1': 0.9504434011476266, 'number': 954}</td>
#       <td>{'precision': 0.9560333761232349, 'recall': 0.9575699132111861, 'f1': 0.9568010277822386, 'number': 3111}</td>
#       <td>{'precision': 0.9696356275303644, 'recall': 0.9937759336099585, 'f1': 0.9815573770491803, 'number': 482}</td>
#       <td>{'precision': 0.8536585365853658, 'recall': 0.8860759493670886, 'f1': 0.8695652173913043, 'number': 79}</td>
#       <td>{'precision': 1.0, 'recall': 0.5, 'f1': 0.6666666666666666, 'number': 2}</td>
#       <td>{'precision': 0.9365962180200222, 'recall': 0.9431531783814058, 'f1': 0.9398632621738524, 'number': 3571}</td>
#       <td>{'precision': 0.9112903225806451, 'recall': 0.8786936236391913, 'f1': 0.894695170229612, 'number': 643}</td>
#       <td>{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}</td>
#       <td>{'precision': 0.9152542372881356, 'recall': 0.9152542372881356, 'f1': 0.9152542372881356, 'number': 59}</td>
#       <td>{'precision': 0.2857142857142857, 'recall': 0.6666666666666666, 'f1': 0.4, 'number': 3}</td>
#       <td>{'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 1}</td>
#       <td>{'precision': 0.8918918918918919, 'recall': 0.9428571428571428, 'f1': 0.9166666666666667, 'number': 35}</td>
#       <td>0.941141</td>
#       <td>0.942566</td>
#       <td>0.941853</td>
#       <td>0.970402</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NOUN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NUM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VERB seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PROPN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: DET seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADV seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: CCONJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PUNCT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: INTJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: X seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: CONJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: SYM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PRT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trainer is attempting to log a value of "{'precision': 0.9022556390977443, 'recall': 1.0, 'f1': 0.9486166007905138, 'number': 120}" of type <class 'dict'> for key "eval/CONJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9217506631299734, 'recall': 0.8622828784119106, 'f1': 0.891025641025641, 'number': 806}" of type <class 'dict'> for key "eval/DJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.575, 'recall': 0.5897435897435898, 'f1': 0.5822784810126582, 'number': 39}" of type <class 'dict'> for key "eval/DP" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.894, 'recall': 0.9371069182389937, 'f1': 0.9150460593654043, 'number': 954}" of type <class 'dict'> for key "eval/DV" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9427100096556164, 'recall': 0.9414979106396657, 'f1': 0.9421035702798327, 'number': 3111}" of type <class 'dict'> for key "eval/ERB" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.967479674796748, 'recall': 0.9875518672199171, 'f1': 0.9774127310061602, 'number': 482}" of type <class 'dict'> for key "eval/ET" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.8148148148148148, 'recall': 0.8354430379746836, 'f1': 0.825, 'number': 79}" of type <class 'dict'> for key "eval/NTJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 1.0, 'recall': 0.5, 'f1': 0.6666666666666666, 'number': 2}" of type <class 'dict'> for key "eval/ONJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.903486750348675, 'recall': 0.9070288434612154, 'f1': 0.9052543320290666, 'number': 3571}" of type <class 'dict'> for key "eval/OUN" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.810930576070901, 'recall': 0.8538102643856921, 'f1': 0.8318181818181819, 'number': 643}" of type <class 'dict'> for key "eval/ROPN" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}" of type <class 'dict'> for key "eval/RT" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.7846153846153846, 'recall': 0.864406779661017, 'f1': 0.8225806451612904, 'number': 59}" of type <class 'dict'> for key "eval/UM" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.2857142857142857, 'recall': 0.6666666666666666, 'f1': 0.4, 'number': 3}" of type <class 'dict'> for key "eval/UNCT" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1}" of type <class 'dict'> for key "eval/YM" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.5142857142857142, 'recall': 0.5142857142857142, 'f1': 0.5142857142857142, 'number': 35}" of type <class 'dict'> for key "eval/_" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NOUN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NUM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VERB seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PROPN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: DET seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADV seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: CCONJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PUNCT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: INTJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: X seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: CONJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: SYM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PRT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trainer is attempting to log a value of "{'precision': 0.9230769230769231, 'recall': 1.0, 'f1': 0.9600000000000001, 'number': 120}" of type <class 'dict'> for key "eval/CONJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.8798017348203222, 'recall': 0.8808933002481389, 'f1': 0.8803471791692499, 'number': 806}" of type <class 'dict'> for key "eval/DJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.6744186046511628, 'recall': 0.7435897435897436, 'f1': 0.7073170731707318, 'number': 39}" of type <class 'dict'> for key "eval/DP" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9284232365145229, 'recall': 0.9381551362683438, 'f1': 0.9332638164754953, 'number': 954}" of type <class 'dict'> for key "eval/DV" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9460408684546615, 'recall': 0.9524268723882996, 'f1': 0.9492231299054942, 'number': 3111}" of type <class 'dict'> for key "eval/ERB" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9754601226993865, 'recall': 0.9896265560165975, 'f1': 0.9824922760041194, 'number': 482}" of type <class 'dict'> for key "eval/ET" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.8461538461538461, 'recall': 0.8354430379746836, 'f1': 0.840764331210191, 'number': 79}" of type <class 'dict'> for key "eval/NTJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 1.0, 'recall': 0.5, 'f1': 0.6666666666666666, 'number': 2}" of type <class 'dict'> for key "eval/ONJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9219052893935198, 'recall': 0.9322318678241389, 'f1': 0.927039821776664, 'number': 3571}" of type <class 'dict'> for key "eval/OUN" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.8742138364779874, 'recall': 0.864696734059098, 'f1': 0.8694292415949961, 'number': 643}" of type <class 'dict'> for key "eval/ROPN" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}" of type <class 'dict'> for key "eval/RT" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.859375, 'recall': 0.9322033898305084, 'f1': 0.8943089430894309, 'number': 59}" of type <class 'dict'> for key "eval/UM" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.125, 'recall': 0.6666666666666666, 'f1': 0.21052631578947367, 'number': 3}" of type <class 'dict'> for key "eval/UNCT" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1}" of type <class 'dict'> for key "eval/YM" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.6122448979591837, 'recall': 0.8571428571428571, 'f1': 0.7142857142857143, 'number': 35}" of type <class 'dict'> for key "eval/_" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NOUN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NUM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VERB seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PROPN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: DET seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADV seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: CCONJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PUNCT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: INTJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: X seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: CONJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: SYM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PRT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.9/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trainer is attempting to log a value of "{'precision': 0.9448818897637795, 'recall': 1.0, 'f1': 0.97165991902834, 'number': 120}" of type <class 'dict'> for key "eval/CONJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9217948717948717, 'recall': 0.892059553349876, 'f1': 0.9066834804539723, 'number': 806}" of type <class 'dict'> for key "eval/DJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9230769230769231, 'recall': 0.9230769230769231, 'f1': 0.9230769230769231, 'number': 39}" of type <class 'dict'> for key "eval/DP" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9460020768431984, 'recall': 0.9549266247379455, 'f1': 0.9504434011476266, 'number': 954}" of type <class 'dict'> for key "eval/DV" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9560333761232349, 'recall': 0.9575699132111861, 'f1': 0.9568010277822386, 'number': 3111}" of type <class 'dict'> for key "eval/ERB" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9696356275303644, 'recall': 0.9937759336099585, 'f1': 0.9815573770491803, 'number': 482}" of type <class 'dict'> for key "eval/ET" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.8536585365853658, 'recall': 0.8860759493670886, 'f1': 0.8695652173913043, 'number': 79}" of type <class 'dict'> for key "eval/NTJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 1.0, 'recall': 0.5, 'f1': 0.6666666666666666, 'number': 2}" of type <class 'dict'> for key "eval/ONJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9365962180200222, 'recall': 0.9431531783814058, 'f1': 0.9398632621738524, 'number': 3571}" of type <class 'dict'> for key "eval/OUN" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9112903225806451, 'recall': 0.8786936236391913, 'f1': 0.894695170229612, 'number': 643}" of type <class 'dict'> for key "eval/ROPN" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}" of type <class 'dict'> for key "eval/RT" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9152542372881356, 'recall': 0.9152542372881356, 'f1': 0.9152542372881356, 'number': 59}" of type <class 'dict'> for key "eval/UM" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.2857142857142857, 'recall': 0.6666666666666666, 'f1': 0.4, 'number': 3}" of type <class 'dict'> for key "eval/UNCT" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 1}" of type <class 'dict'> for key "eval/YM" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.8918918918918919, 'recall': 0.9428571428571428, 'f1': 0.9166666666666667, 'number': 35}" of type <class 'dict'> for key "eval/_" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
#     <div>
#
#       <progress value='89' max='89' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [89/89 00:04]
#     </div>
# Trainer is attempting to log a value of "{'precision': 0.9448818897637795, 'recall': 1.0, 'f1': 0.97165991902834, 'number': 120}" of type <class 'dict'> for key "eval/CONJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9217948717948717, 'recall': 0.892059553349876, 'f1': 0.9066834804539723, 'number': 806}" of type <class 'dict'> for key "eval/DJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9230769230769231, 'recall': 0.9230769230769231, 'f1': 0.9230769230769231, 'number': 39}" of type <class 'dict'> for key "eval/DP" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9460020768431984, 'recall': 0.9549266247379455, 'f1': 0.9504434011476266, 'number': 954}" of type <class 'dict'> for key "eval/DV" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9560333761232349, 'recall': 0.9575699132111861, 'f1': 0.9568010277822386, 'number': 3111}" of type <class 'dict'> for key "eval/ERB" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9696356275303644, 'recall': 0.9937759336099585, 'f1': 0.9815573770491803, 'number': 482}" of type <class 'dict'> for key "eval/ET" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.8536585365853658, 'recall': 0.8860759493670886, 'f1': 0.8695652173913043, 'number': 79}" of type <class 'dict'> for key "eval/NTJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 1.0, 'recall': 0.5, 'f1': 0.6666666666666666, 'number': 2}" of type <class 'dict'> for key "eval/ONJ" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9365962180200222, 'recall': 0.9431531783814058, 'f1': 0.9398632621738524, 'number': 3571}" of type <class 'dict'> for key "eval/OUN" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9112903225806451, 'recall': 0.8786936236391913, 'f1': 0.894695170229612, 'number': 643}" of type <class 'dict'> for key "eval/ROPN" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}" of type <class 'dict'> for key "eval/RT" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.9152542372881356, 'recall': 0.9152542372881356, 'f1': 0.9152542372881356, 'number': 59}" of type <class 'dict'> for key "eval/UM" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.2857142857142857, 'recall': 0.6666666666666666, 'f1': 0.4, 'number': 3}" of type <class 'dict'> for key "eval/UNCT" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 1}" of type <class 'dict'> for key "eval/YM" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'precision': 0.8918918918918919, 'recall': 0.9428571428571428, 'f1': 0.9166666666666667, 'number': 35}" of type <class 'dict'> for key "eval/_" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# {'eval_loss': 0.12514713406562805,
#  'eval_CONJ': {'precision': 0.9448818897637795,
#   'recall': 1.0,
#   'f1': 0.97165991902834,
#   'number': 120},
#  'eval_DJ': {'precision': 0.9217948717948717,
#   'recall': 0.892059553349876,
#   'f1': 0.9066834804539723,
#   'number': 806},
#  'eval_DP': {'precision': 0.9230769230769231,
#   'recall': 0.9230769230769231,
#   'f1': 0.9230769230769231,
#   'number': 39},
#  'eval_DV': {'precision': 0.9460020768431984,
#   'recall': 0.9549266247379455,
#   'f1': 0.9504434011476266,
#   'number': 954},
#  'eval_ERB': {'precision': 0.9560333761232349,
#   'recall': 0.9575699132111861,
#   'f1': 0.9568010277822386,
#   'number': 3111},
#  'eval_ET': {'precision': 0.9696356275303644,
#   'recall': 0.9937759336099585,
#   'f1': 0.9815573770491803,
#   'number': 482},
#  'eval_NTJ': {'precision': 0.8536585365853658,
#   'recall': 0.8860759493670886,
#   'f1': 0.8695652173913043,
#   'number': 79},
#  'eval_ONJ': {'precision': 1.0,
#   'recall': 0.5,
#   'f1': 0.6666666666666666,
#   'number': 2},
#  'eval_OUN': {'precision': 0.9365962180200222,
#   'recall': 0.9431531783814058,
#   'f1': 0.9398632621738524,
#   'number': 3571},
#  'eval_ROPN': {'precision': 0.9112903225806451,
#   'recall': 0.8786936236391913,
#   'f1': 0.894695170229612,
#   'number': 643},
#  'eval_RT': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2},
#  'eval_UM': {'precision': 0.9152542372881356,
#   'recall': 0.9152542372881356,
#   'f1': 0.9152542372881356,
#   'number': 59},
#  'eval_UNCT': {'precision': 0.2857142857142857,
#   'recall': 0.6666666666666666,
#   'f1': 0.4,
#   'number': 3},
#  'eval_YM': {'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 1},
#  'eval__': {'precision': 0.8918918918918919,
#   'recall': 0.9428571428571428,
#   'f1': 0.9166666666666667,
#   'number': 35},
#  'eval_overall_precision': 0.9411408990122959,
#  'eval_overall_recall': 0.9425658625214495,
#  'eval_overall_f1': 0.9418528417973674,
#  'eval_overall_accuracy': 0.9704015099519561,
#  'eval_runtime': 6.4439,
#  'eval_samples_per_second': 220.054,
#  'eval_steps_per_second': 13.812,
#  'epoch': 3.0}

# %%
trainer.save_model('bert-base-multilingual-cased.model')
# !tar cvfz bert-base-multilingual-cased.tar.gz bert-base-multilingual-cased.model/
# !mv bert-base-multilingual-cased.tar.gz  /content/drive/MyDrive/
# Out:
# bert-base-multilingual-cased.model/
# bert-base-multilingual-cased.model/config.json
# bert-base-multilingual-cased.model/training_args.bin
# bert-base-multilingual-cased.model/pytorch_model.bin
# bert-base-multilingual-cased.model/special_tokens_map.json
# bert-base-multilingual-cased.model/tokenizer_config.json
# bert-base-multilingual-cased.model/tokenizer.json
# bert-base-multilingual-cased.model/vocab.txt
